# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os


# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import tensorflow as tf
# Enable mixed precision
tf.keras.mixed_precision.set_global_policy('mixed_float16')

# %%
CATEGORY = "Women Tops & Tunics" 
num_attributes = 10
TRAIN_TEST_SPLIT = 0.90
IM_WIDTH = IM_HEIGHT = 384

# %%
import os

category_path = CATEGORY.replace(" ", "_")
directory_path = f'/kaggle/input/sorted-train/sorted_images/{category_path}'  # Use CATEGORY here

# Get the list of files in the directory
files = os.listdir(directory_path)

# Filter out directories from the list to count only files
num_files = sum(os.path.isfile(os.path.join(directory_path, file)) for file in files)

print(f"Number of files in the directory for {CATEGORY}: {num_files}")
# Out:
# Number of files in the directory for Women Tops & Tunics: 19004

# %%
import pandas as pd

# Load train.csv
def load_data(file_path, category):
    # Load the dataset
    df = pd.read_csv(file_path)
    
    # Filter for the specified category
    filtered_df = df[df['Category'] == category].copy()
    
    return filtered_df

file_path = '/kaggle/input/visual-taxonomy/train.csv'  # Ensure this path is correct

# Load the filtered data
filtered_data = load_data(file_path, CATEGORY)

# %%
# 1. Function to Generate Attribute Names Based on the Number of Attributes
def generate_attributes(num_attributes):
    """
    Generate a list of attribute names based on the specified number of attributes.
    e.g., if num_attributes = 5, it will generate ['attr_1', 'attr_2', ..., 'attr_5']
    """
    return [f'attr_{i+1}' for i in range(num_attributes)]

# 2. Collect Unique Attribute Values Dynamically
def collect_unique_values(df, num_attributes):
    """
    Collect unique attribute values for the specified number of attributes dynamically.
    """
    attributes = generate_attributes(num_attributes)  # Dynamically generate attribute names
    unique_values = {attr: set() for attr in attributes}  # Create a set for each attribute
    
    for attr in attributes:
        if attr in df.columns:  # Ensure the attribute exists in the dataframe
            # Update the set with unique non-null values
            unique_values[attr].update(df[attr].dropna().unique())
    
    return unique_values

# 3. Specify the Number of Attributes You Want to Extract
#num_attributes = 5  # Change this number to the desired number of attributes (up to 10)

# Collect unique values from the filtered data for the specified number of attributes
unique_values = collect_unique_values(filtered_data, num_attributes)

# 4. Print the unique values for verification
print(unique_values)
# Out:
# {'attr_1': {'blue', 'green', 'black', 'maroon', 'peach', 'pink', 'multicolor', 'red', 'navy blue', 'yellow', 'default', 'white'}, 'attr_2': {'fitted', 'boxy', 'default', 'regular'}, 'attr_3': {'regular', 'crop'}, 'attr_4': {'stylised', 'v-neck', 'high', 'sweetheart neck', 'default', 'round neck', 'square neck'}, 'attr_5': {'casual', 'party'}, 'attr_6': {'printed', 'default', 'solid'}, 'attr_7': {'graphic', 'solid', 'floral', 'typography', 'default', 'quirky'}, 'attr_8': {'three-quarter sleeves', 'long sleeves', 'sleeveless', 'short sleeves'}, 'attr_9': {'regular sleeves', 'default', 'puff sleeves', 'sleeveless'}, 'attr_10': {'ruffles', 'tie-ups', 'knitted', 'applique', 'waist tie-ups', 'default'}}

# %%
# Create dataset_dict from unique values
def create_dataset_dict(unique_values, dummy_value='dummy'):
    dataset_dict = {attr: {} for attr in unique_values.keys()}
    
    for attr, values in unique_values.items():
        sorted_values = sorted(values)  # Sort unique values
        for i, value in enumerate(sorted_values):
            dataset_dict[attr][i] = value  # Assign numeric keys
        
        dataset_dict[attr][len(sorted_values)] = dummy_value  # Add dummy value at the end
    
    return dataset_dict

# Create the dataset dictionary
dataset_dict = create_dataset_dict(unique_values)

# %%
# Create alias dictionaries
def create_alias_dicts(dataset_dict):
    # Create a new dictionary for alias mappings
    alias_dicts = {}
    
    for attr in dataset_dict.keys():
        # Create alias for each attribute and store in the new dictionary
        alias_dicts[f'{attr}_alias'] = {value: i for i, value in dataset_dict[attr].items()}
    
    # Add the alias dictionaries to the original dataset_dict
    dataset_dict.update(alias_dicts)
    
    return dataset_dict

# Add alias dictionaries to dataset_dict
dataset_dict = create_alias_dicts(dataset_dict)

# Print dataset_dict to verify the mappings
print(dataset_dict)
# Out:
# {'attr_1': {0: 'black', 1: 'blue', 2: 'default', 3: 'green', 4: 'maroon', 5: 'multicolor', 6: 'navy blue', 7: 'peach', 8: 'pink', 9: 'red', 10: 'white', 11: 'yellow', 12: 'dummy'}, 'attr_2': {0: 'boxy', 1: 'default', 2: 'fitted', 3: 'regular', 4: 'dummy'}, 'attr_3': {0: 'crop', 1: 'regular', 2: 'dummy'}, 'attr_4': {0: 'default', 1: 'high', 2: 'round neck', 3: 'square neck', 4: 'stylised', 5: 'sweetheart neck', 6: 'v-neck', 7: 'dummy'}, 'attr_5': {0: 'casual', 1: 'party', 2: 'dummy'}, 'attr_6': {0: 'default', 1: 'printed', 2: 'solid', 3: 'dummy'}, 'attr_7': {0: 'default', 1: 'floral', 2: 'graphic', 3: 'quirky', 4: 'solid', 5: 'typography', 6: 'dummy'}, 'attr_8': {0: 'long sleeves', 1: 'short sleeves', 2: 'sleeveless', 3: 'three-quarter sleeves', 4: 'dummy'}, 'attr_9': {0: 'default', 1: 'puff sleeves', 2: 'regular sleeves', 3: 'sleeveless', 4: 'dummy'}, 'attr_10': {0: 'applique', 1: 'default', 2: 'knitted', 3: 'ruffles', 4: 'tie-ups', 5: 'waist tie-ups', 6: 'dummy'}, 'attr_1_alias': {'black': 0, 'blue': 1, 'default': 2, 'green': 3, 'maroon': 4, 'multicolor': 5, 'navy blue': 6, 'peach': 7, 'pink': 8, 'red': 9, 'white': 10, 'yellow': 11, 'dummy': 12}, 'attr_2_alias': {'boxy': 0, 'default': 1, 'fitted': 2, 'regular': 3, 'dummy': 4}, 'attr_3_alias': {'crop': 0, 'regular': 1, 'dummy': 2}, 'attr_4_alias': {'default': 0, 'high': 1, 'round neck': 2, 'square neck': 3, 'stylised': 4, 'sweetheart neck': 5, 'v-neck': 6, 'dummy': 7}, 'attr_5_alias': {'casual': 0, 'party': 1, 'dummy': 2}, 'attr_6_alias': {'default': 0, 'printed': 1, 'solid': 2, 'dummy': 3}, 'attr_7_alias': {'default': 0, 'floral': 1, 'graphic': 2, 'quirky': 3, 'solid': 4, 'typography': 5, 'dummy': 6}, 'attr_8_alias': {'long sleeves': 0, 'short sleeves': 1, 'sleeveless': 2, 'three-quarter sleeves': 3, 'dummy': 4}, 'attr_9_alias': {'default': 0, 'puff sleeves': 1, 'regular sleeves': 2, 'sleeveless': 3, 'dummy': 4}, 'attr_10_alias': {'applique': 0, 'default': 1, 'knitted': 2, 'ruffles': 3, 'tie-ups': 4, 'waist tie-ups': 5, 'dummy': 6}}

# %%
import numpy as np 
import pandas as pd
import glob
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# 1. Function to Generate Attribute Names Dynamically Based on the Number of Attributes
def generate_attributes(num_attributes):
    """
    Generate a list of attribute names based on the specified number of attributes.
    e.g., if num_attributes = 5, it will generate ['attr_1', 'attr_2', ..., 'attr_5']
    """
    return [f'attr_{i+1}' for i in range(num_attributes)]

# 2. Main Function to Parse Dataset
def parse_dataset(dataset_path, csv_path, category, num_attributes, ext='jpg', dummy_value='dummy', max_id=70378):
    """
    Extract dataset information based on the specified category, checking IDs from 0 to max_id.
    Skips images whose IDs are not in the CSV.
    Assigns dummy values only to missing attributes for found IDs.
    Dynamically handles up to the specified number of attributes.
    """
    # Load the CSV file
    df_csv = pd.read_csv(csv_path)
    
    # Replace any null values with the dummy value for attributes
    df_csv.fillna(dummy_value, inplace=True)

    # Filter by the specified category (e.g., 'Men Tshirts')
    df_csv = df_csv[df_csv['Category'] == category]
    
    # Convert the 'id' column to int to ensure it matches the image ID format
    df_csv['id'] = df_csv['id'].astype(int)

    # Generate the list of attribute names based on the number of attributes
    attributes = generate_attributes(num_attributes)

    # Helper function to parse information for a single image ID
    def parse_info_for_id(image_id):
        if image_id in df_csv['id'].values:
            row = df_csv[df_csv['id'] == image_id].iloc[0]
            # Return attribute values dynamically
            return tuple(row[attr] for attr in attributes)
        else:
            # Skip IDs that are not found in the CSV (return None to skip)
            return None
    
    # Initialize records list to store data
    records = []
    
    # Iterate over the range of IDs from 0 to max_id (70378)
    for image_id in range(0, max_id + 1):
        result = parse_info_for_id(image_id)
        if result is not None:
            records.append((*result, f"{dataset_path}/{str(image_id).zfill(6)}.{ext}"))  # Add the file path

    # Create DataFrame from the collected records
    df = pd.DataFrame(records, columns=[*attributes, 'file'])

    return df

# Example usage
dataset_folder_name = f'/kaggle/input/sorted-train/sorted_images/{category_path}'
csv_file_path = '/kaggle/input/visual-taxonomy/train.csv'
category = CATEGORY


# Parse the dataset
df = parse_dataset(dataset_folder_name, csv_file_path, category, num_attributes)
column_names = [f'attr{i+1}' for i in range(num_attributes)] + ['file']
df.columns = column_names
print(df.head())
# Out:
#        attr1    attr2    attr3       attr4   attr5    attr6       attr7  \
# 0      black  regular    dummy       dummy   dummy    dummy       dummy
# 1  navy blue   fitted     crop        high  casual  default       solid
# 2        red  regular  regular  round neck  casual  printed  typography
# 3    default   fitted     crop    stylised  casual    solid       solid
# 4    default     boxy  regular  round neck  casual  printed  typography
#
#            attr8            attr9   attr10  \
# 0          dummy  regular sleeves    dummy
# 1  short sleeves          default  knitted
# 2     sleeveless       sleeveless    dummy
# 3  short sleeves  regular sleeves  default
# 4  short sleeves          default    dummy
#
#                                                 file
# 0  /kaggle/input/sorted-train/sorted_images/Women...
# 1  /kaggle/input/sorted-train/sorted_images/Women...
# 2  /kaggle/input/sorted-train/sorted_images/Women...
# 3  /kaggle/input/sorted-train/sorted_images/Women...
# 4  /kaggle/input/sorted-train/sorted_images/Women...

# %%
# Get the shape of the DataFrame
df_size = df.shape

# Print the number of rows and columns
print(f"The DataFrame has {df_size[0]} rows and {df_size[1]} columns.")
# Out:
# The DataFrame has 19004 rows and 11 columns.

# %%
import matplotlib.pyplot as plt

# Function to plot distribution of a pandas series using Matplotlib
def plot_distribution(pd_series):
    labels = pd_series.value_counts().index.tolist()
    counts = pd_series.value_counts().values.tolist()

    # Create a pie chart using Matplotlib
    plt.figure(figsize=(8, 8))
    plt.pie(counts, labels=labels, autopct='%1.1f%%', startangle=90, wedgeprops={'edgecolor': 'black'})
    
    # Add a title to the plot
    plt.title(f'Distribution for {pd_series.name}')
    
    # Display the pie chart
    plt.show()

# %%
plot_distribution(df['attr2'])

# %%
from keras.utils import to_categorical
from PIL import Image
import numpy as np
import pandas as pd

class TrainMDataGenerator():
    """
    Data generator for the UTKFace dataset. This class should be used when training our Keras multi-output model.
    Dynamically handles any number of attributes.
    """
    def __init__(self, df, num_attributes):
        self.df = df
        self.num_attributes = num_attributes  # Number of attributes to process dynamically

    def generate_attributes(self):
        """
        Generate a list of attribute names based on the number of attributes.
        e.g., if num_attributes = 5, it will generate ['attr_1', 'attr_2', ..., 'attr_5']
        """
        return [f'attr_{i+1}' for i in range(self.num_attributes)]
    
    def generate_alias_mappings(self):
        """
        Converts alias to id for all attributes dynamically.
        """
        for i in range(1, self.num_attributes + 1):
            attr_alias = f'attr_{i}_alias'
            attr_col = f'attr_{i}'
            self.df[attr_col] = self.df[f'attr{i}'].map(lambda attr: dataset_dict[attr_alias][attr])
    
    def generate_split_indexes(self):
        """
        Generate train, validation, and test indexes based on the dataset split.
        """
        p = np.random.permutation(len(self.df))
        train_up_to = int(len(self.df) * TRAIN_TEST_SPLIT)
        train_idx = p[:train_up_to]
        valid_idx = p[train_up_to:]
   
        
        # Generate alias mappings dynamically for all attributes
        self.generate_alias_mappings()
        
        return train_idx, valid_idx
    
    def preprocess_image(self, img_path):
        """
        Used to perform some minor preprocessing on the image before inputting into the network.
        """
        im = Image.open(img_path)
        im = im.resize((IM_WIDTH, IM_HEIGHT))
        im = np.array(im) / 255.0
        im = im * 2 - 1  # Normalize to -1 to 1
        
        return im
        
    def generate_images(self, image_idx, is_training, batch_size=16):
        """
        Used to generate a batch with images when training/testing/validating our Keras model.
        """

        # Dynamically create arrays to store batched data for all attributes
        images = []
        attr_batches = {f'attr{i+1}s': [] for i in range(self.num_attributes)}

        while True:
            for idx in image_idx:
                person = self.df.iloc[idx]
                file = person['file']

                # Preprocess the image
                im = self.preprocess_image(file)
                images.append(im)

                # Convert attributes to categorical and append them to respective lists dynamically
                for i in range(1, self.num_attributes + 1):
                    attr_col = f'attr_{i}'
                    attr_value = person[attr_col]
                    attr_batches[f'attr{i}s'].append(to_categorical(attr_value, len(dataset_dict[attr_col])))

                # Yielding condition
                if len(images) >= batch_size:
                    # Prepare the list of categorical attribute arrays
                    attr_outputs = [np.array(attr_batches[f'attr{i}s']) for i in range(1, self.num_attributes + 1)]
                    # Yield a tuple of (input batch, label batch) where each label batch is a list of arrays
                    yield np.array(images), tuple(attr_outputs)

                    # Reset the lists for the next batch
                    images = []
                    attr_batches = {f'attr{i+1}s': [] for i in range(self.num_attributes)}

            # If not training (e.g., in validation or testing), exit after one pass
            if not is_training:
                break

# Example usage
data_generator = TrainMDataGenerator(df, num_attributes)  # Adjust num_attributes as needed (up to 10)
train_idx, valid_idx = data_generator.generate_split_indexes()

# %%
from keras.applications import EfficientNetV2L
from keras.optimizers import AdamW
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from keras.layers import GlobalAveragePooling2D, Dense, Dropout, Input
from keras.models import Model
import tensorflow as tf
import pickle

# Define initial learning rate and epochs
init_lr = 0.00003
epochs = 100

# AdamW optimizer
opt = AdamW(learning_rate=init_lr)

# Define the number of attributes and base weight
base_weight = 1.0  # Minimum weight for the attribute with the least unique values
max_weight = 3.0   # Maximum weight for the attribute with the most unique values

# Define a list of attribute names
attr_names = [f'attr{i+1}_output' for i in range(num_attributes)]

# Define a dictionary of unique values count for each attribute
unique_values_count = {f'attr_{i+1}': len(dataset_dict[f'attr_{i+1}_alias']) for i in range(num_attributes)}
max_unique_count = max(unique_values_count.values())

# Calculate total sum of unique values for normalization
total_unique_values = sum(unique_values_count.values())

# Assign weights based on unique values proportion with scaling
loss_weights_dict = {
    name: 1.5 # Scale from 2 to 15 unique values
    for name in attr_names
}

# Clip weights to ensure they don't exceed max_weight


# Custom loss function to ignore the last class
def custom_loss_function(y_true, y_pred):
    # Exclude the last class (dummy) from the loss calculation
    y_true = tf.cast(y_true[:, :-1], tf.float32)  # Exclude last class
    y_pred = y_pred[:, :-1]  # Exclude last class
    loss = tf.keras.backend.categorical_crossentropy(y_true, y_pred)  # Use tf.keras.backend
    return loss

# Define loss functions and metrics dynamically
loss_dict = {name: custom_loss_function for name in attr_names}
metrics_dict = {name: 'accuracy' for name in attr_names}

# Build EfficientNet V2S model
def build_efficientnetv2s_model(num_attributes):
    base_model = EfficientNetV2L(input_shape=(IM_HEIGHT, IM_WIDTH, 3), include_top=False, weights='imagenet')
    base_model.trainable = True  # Keep all layers unfrozen
    
    inputs = base_model.input
    x = base_model.output

    # Create branches for each attribute
    branches = []
    for i in range(num_attributes):
        num_outputs = unique_values_count[f'attr_{i+1}']  # Get number of outputs for the current attribute
        x_branch = GlobalAveragePooling2D()(x)  # Add Global Average Pooling for each branch
        
        x_branch = Dropout(0.5)(x_branch)              # Dropout layer
        x_branch = Dense(num_outputs, activation='softmax', name=f'attr{i+1}_output')(x_branch)  # Output layer
        branches.append(x_branch)

    model = Model(inputs=inputs, outputs=branches, name="efficientnetv2s_model")
    return model

model = build_efficientnetv2s_model(num_attributes)

# Compile the model
model.compile(optimizer=opt, 
              loss=loss_dict,
              loss_weights=loss_weights_dict,
              metrics=metrics_dict)

# Callbacks
callbacks = [
    ModelCheckpoint("./model_checkpoint.keras", monitor='val_loss', save_best_only=True),
    EarlyStopping(monitor='val_loss', patience=5, verbose=1, restore_best_weights=True)
]

# Training
batch_size = 32
valid_batch_size = 32
train_gen = data_generator.generate_images(train_idx, is_training=True, batch_size=batch_size)
valid_gen = data_generator.generate_images(valid_idx, is_training=True, batch_size=valid_batch_size)


history = model.fit(train_gen,
                    steps_per_epoch=len(train_idx) // batch_size,
                    epochs=epochs,
                    callbacks=callbacks,
                    validation_data=valid_gen,
                    validation_steps=len(valid_idx) // valid_batch_size)

# Save training history
with open('./training_history.pkl', 'wb') as f:
    pickle.dump(history.history, f)

# Output the model summary for verification
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-l_notop.h5
# 473176280/473176280 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731742702.396548      71 service.cc:145] XLA service 0x7a17e80020e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1731742702.396632      71 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1731742702.396637      71 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# 2024-11-16 07:40:58.930910: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f16[32,96,96,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,193,193,32]{3,2,1,0}, f16[128,3,3,32]{3,2,1,0}), window={size=3x3 stride=2x2}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-11-16 07:40:59.199080: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.268258971s
# Trying algorithm eng0{} for conv (f16[32,96,96,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,193,193,32]{3,2,1,0}, f16[128,3,3,32]{3,2,1,0}), window={size=3x3 stride=2x2}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-11-16 07:41:02.198037: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f16[32,96,96,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,96,96,64]{3,2,1,0}, f16[256,3,3,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-11-16 07:41:05.917769: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 4.719808222s
# Trying algorithm eng0{} for conv (f16[32,96,96,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,96,96,64]{3,2,1,0}, f16[256,3,3,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-11-16 07:41:07.982249: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f16[32,48,48,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,97,97,64]{3,2,1,0}, f16[256,3,3,64]{3,2,1,0}), window={size=3x3 stride=2x2}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-11-16 07:41:08.276860: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.294712623s
# Trying algorithm eng0{} for conv (f16[32,48,48,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,97,97,64]{3,2,1,0}, f16[256,3,3,64]{3,2,1,0}), window={size=3x3 stride=2x2}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-11-16 07:41:10.159560: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f16[32,48,48,384]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,48,48,96]{3,2,1,0}, f16[384,3,3,96]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-11-16 07:41:11.346254: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.186842692s
# Trying algorithm eng0{} for conv (f16[32,48,48,384]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,48,48,96]{3,2,1,0}, f16[384,3,3,96]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-11-16 07:41:29.331099: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{} for conv (f16[32,3,3,32]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,192,192,32]{3,2,1,0}, f16[32,192,192,32]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-11-16 07:41:29.469011: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.138116026s
# Trying algorithm eng19{} for conv (f16[32,3,3,32]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,192,192,32]{3,2,1,0}, f16[32,192,192,32]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-11-16 07:41:30.469216: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f16[32,3,3,32]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,192,192,32]{3,2,1,0}, f16[32,192,192,32]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-11-16 07:41:40.943980: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 11.474870039s
# Trying algorithm eng0{} for conv (f16[32,3,3,32]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,192,192,32]{3,2,1,0}, f16[32,192,192,32]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-11-16 07:41:42.443523: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{} for conv (f16[128,3,3,32]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,193,193,32]{3,2,1,0}, f16[32,96,96,128]{3,2,1,0}), window={size=3x3 stride=2x2}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-11-16 07:41:44.575706: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 3.13226395s
# Trying algorithm eng19{} for conv (f16[128,3,3,32]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,193,193,32]{3,2,1,0}, f16[32,96,96,128]{3,2,1,0}), window={size=3x3 stride=2x2}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-11-16 07:41:45.575904: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f16[128,3,3,32]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,193,193,32]{3,2,1,0}, f16[32,96,96,128]{3,2,1,0}), window={size=3x3 stride=2x2}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-11-16 07:42:00.141442: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 15.565623555s
# Trying algorithm eng0{} for conv (f16[128,3,3,32]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,193,193,32]{3,2,1,0}, f16[32,96,96,128]{3,2,1,0}), window={size=3x3 stride=2x2}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-11-16 07:42:02.527181: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{} for conv (f16[256,3,3,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,96,96,64]{3,2,1,0}, f16[32,96,96,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-11-16 07:42:07.141432: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 5.614424471s
# Trying algorithm eng19{} for conv (f16[256,3,3,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,96,96,64]{3,2,1,0}, f16[32,96,96,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-11-16 07:42:08.595380: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{} for conv (f16[256,3,3,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,97,97,64]{3,2,1,0}, f16[32,48,48,256]{3,2,1,0}), window={size=3x3 stride=2x2}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-11-16 07:42:11.266788: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 3.671573117s
# Trying algorithm eng19{} for conv (f16[256,3,3,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,97,97,64]{3,2,1,0}, f16[32,48,48,256]{3,2,1,0}), window={size=3x3 stride=2x2}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-11-16 07:42:13.010415: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f16[384,3,3,96]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,48,48,96]{3,2,1,0}, f16[32,48,48,384]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-11-16 07:42:53.037726: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 41.027471567s
# Trying algorithm eng0{} for conv (f16[384,3,3,96]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,48,48,96]{3,2,1,0}, f16[32,48,48,384]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-11-16 07:42:55.354328: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f16[384,1,1,96]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,48,48,96]{3,2,1,0}, f16[32,48,48,384]{3,2,1,0}), window={size=1x1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-11-16 07:42:57.577370: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 3.223204534s
# Trying algorithm eng0{} for conv (f16[384,1,1,96]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,48,48,96]{3,2,1,0}, f16[32,48,48,384]{3,2,1,0}), window={size=1x1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-11-16 07:43:00.432252: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f16[1344,1,1,224]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,24,24,224]{3,2,1,0}, f16[32,24,24,1344]{3,2,1,0}), window={size=1x1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-11-16 07:43:01.110304: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.67814017s
# Trying algorithm eng0{} for conv (f16[1344,1,1,224]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,24,24,224]{3,2,1,0}, f16[32,24,24,1344]{3,2,1,0}), window={size=1x1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# I0000 00:00:1731743442.480642      71 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 1652s 1s/step - attr10_output_accuracy: 0.2097 - attr1_output_accuracy: 0.2339 - attr2_output_accuracy: 0.3977 - attr3_output_accuracy: 0.4981 - attr4_output_accuracy: 0.3741 - attr5_output_accuracy: 0.5688 - attr6_output_accuracy: 0.5321 - attr7_output_accuracy: 0.4610 - attr8_output_accuracy: 0.4326 - attr9_output_accuracy: 0.4342 - loss: 10.1982 - val_attr10_output_accuracy: 0.2638 - val_attr1_output_accuracy: 0.5530 - val_attr2_output_accuracy: 0.5387 - val_attr3_output_accuracy: 0.6218 - val_attr4_output_accuracy: 0.5784 - val_attr5_output_accuracy: 0.6483 - val_attr6_output_accuracy: 0.6472 - val_attr7_output_accuracy: 0.6133 - val_attr8_output_accuracy: 0.6753 - val_attr9_output_accuracy: 0.5535 - val_loss: 4.4404
# Epoch 2/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 693s 1s/step - attr10_output_accuracy: 0.2528 - attr1_output_accuracy: 0.5381 - attr2_output_accuracy: 0.5416 - attr3_output_accuracy: 0.5941 - attr4_output_accuracy: 0.5730 - attr5_output_accuracy: 0.6400 - attr6_output_accuracy: 0.6470 - attr7_output_accuracy: 0.5938 - attr8_output_accuracy: 0.6578 - attr9_output_accuracy: 0.5821 - loss: 4.7854 - val_attr10_output_accuracy: 0.2855 - val_attr1_output_accuracy: 0.5911 - val_attr2_output_accuracy: 0.5535 - val_attr3_output_accuracy: 0.6298 - val_attr4_output_accuracy: 0.5953 - val_attr5_output_accuracy: 0.6494 - val_attr6_output_accuracy: 0.6557 - val_attr7_output_accuracy: 0.6218 - val_attr8_output_accuracy: 0.6859 - val_attr9_output_accuracy: 0.5731 - val_loss: 3.6801
# Epoch 3/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 693s 1s/step - attr10_output_accuracy: 0.2763 - attr1_output_accuracy: 0.5946 - attr2_output_accuracy: 0.5744 - attr3_output_accuracy: 0.6082 - attr4_output_accuracy: 0.6090 - attr5_output_accuracy: 0.6466 - attr6_output_accuracy: 0.6615 - attr7_output_accuracy: 0.6110 - attr8_output_accuracy: 0.6761 - attr9_output_accuracy: 0.6068 - loss: 3.7183 - val_attr10_output_accuracy: 0.2918 - val_attr1_output_accuracy: 0.6017 - val_attr2_output_accuracy: 0.5572 - val_attr3_output_accuracy: 0.6287 - val_attr4_output_accuracy: 0.6107 - val_attr5_output_accuracy: 0.6483 - val_attr6_output_accuracy: 0.6531 - val_attr7_output_accuracy: 0.6229 - val_attr8_output_accuracy: 0.6907 - val_attr9_output_accuracy: 0.5715 - val_loss: 3.3853
# Epoch 4/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 683s 1s/step - attr10_output_accuracy: 0.2908 - attr1_output_accuracy: 0.6291 - attr2_output_accuracy: 0.5990 - attr3_output_accuracy: 0.6213 - attr4_output_accuracy: 0.6296 - attr5_output_accuracy: 0.6427 - attr6_output_accuracy: 0.6663 - attr7_output_accuracy: 0.6242 - attr8_output_accuracy: 0.6853 - attr9_output_accuracy: 0.6229 - loss: 3.0170 - val_attr10_output_accuracy: 0.2871 - val_attr1_output_accuracy: 0.6102 - val_attr2_output_accuracy: 0.5646 - val_attr3_output_accuracy: 0.6239 - val_attr4_output_accuracy: 0.6096 - val_attr5_output_accuracy: 0.6520 - val_attr6_output_accuracy: 0.6562 - val_attr7_output_accuracy: 0.6239 - val_attr8_output_accuracy: 0.6923 - val_attr9_output_accuracy: 0.5805 - val_loss: 3.3579
# Epoch 5/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 667s 1s/step - attr10_output_accuracy: 0.3061 - attr1_output_accuracy: 0.6478 - attr2_output_accuracy: 0.6186 - attr3_output_accuracy: 0.6338 - attr4_output_accuracy: 0.6482 - attr5_output_accuracy: 0.6492 - attr6_output_accuracy: 0.6719 - attr7_output_accuracy: 0.6344 - attr8_output_accuracy: 0.6976 - attr9_output_accuracy: 0.6297 - loss: 2.4695 - val_attr10_output_accuracy: 0.2934 - val_attr1_output_accuracy: 0.6081 - val_attr2_output_accuracy: 0.5683 - val_attr3_output_accuracy: 0.6271 - val_attr4_output_accuracy: 0.6075 - val_attr5_output_accuracy: 0.6499 - val_attr6_output_accuracy: 0.6536 - val_attr7_output_accuracy: 0.6245 - val_attr8_output_accuracy: 0.6901 - val_attr9_output_accuracy: 0.5816 - val_loss: 3.3747
# Epoch 6/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 665s 1s/step - attr10_output_accuracy: 0.3221 - attr1_output_accuracy: 0.6683 - attr2_output_accuracy: 0.6367 - attr3_output_accuracy: 0.6459 - attr4_output_accuracy: 0.6587 - attr5_output_accuracy: 0.6456 - attr6_output_accuracy: 0.6803 - attr7_output_accuracy: 0.6462 - attr8_output_accuracy: 0.7002 - attr9_output_accuracy: 0.6377 - loss: 1.9907 - val_attr10_output_accuracy: 0.2897 - val_attr1_output_accuracy: 0.6081 - val_attr2_output_accuracy: 0.5715 - val_attr3_output_accuracy: 0.6292 - val_attr4_output_accuracy: 0.6107 - val_attr5_output_accuracy: 0.6472 - val_attr6_output_accuracy: 0.6504 - val_attr7_output_accuracy: 0.6245 - val_attr8_output_accuracy: 0.6880 - val_attr9_output_accuracy: 0.5842 - val_loss: 3.4799
# Epoch 7/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 664s 1s/step - attr10_output_accuracy: 0.3359 - attr1_output_accuracy: 0.6824 - attr2_output_accuracy: 0.6533 - attr3_output_accuracy: 0.6591 - attr4_output_accuracy: 0.6734 - attr5_output_accuracy: 0.6479 - attr6_output_accuracy: 0.6846 - attr7_output_accuracy: 0.6531 - attr8_output_accuracy: 0.7073 - attr9_output_accuracy: 0.6430 - loss: 1.6046 - val_attr10_output_accuracy: 0.2908 - val_attr1_output_accuracy: 0.6112 - val_attr2_output_accuracy: 0.5752 - val_attr3_output_accuracy: 0.6192 - val_attr4_output_accuracy: 0.6054 - val_attr5_output_accuracy: 0.6483 - val_attr6_output_accuracy: 0.6557 - val_attr7_output_accuracy: 0.6271 - val_attr8_output_accuracy: 0.6907 - val_attr9_output_accuracy: 0.5821 - val_loss: 3.5696
# Epoch 8/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 667s 1s/step - attr10_output_accuracy: 0.3461 - attr1_output_accuracy: 0.6970 - attr2_output_accuracy: 0.6611 - attr3_output_accuracy: 0.6655 - attr4_output_accuracy: 0.6785 - attr5_output_accuracy: 0.6500 - attr6_output_accuracy: 0.6882 - attr7_output_accuracy: 0.6608 - attr8_output_accuracy: 0.7089 - attr9_output_accuracy: 0.6464 - loss: 1.3195 - val_attr10_output_accuracy: 0.2881 - val_attr1_output_accuracy: 0.6065 - val_attr2_output_accuracy: 0.5588 - val_attr3_output_accuracy: 0.6335 - val_attr4_output_accuracy: 0.6181 - val_attr5_output_accuracy: 0.6467 - val_attr6_output_accuracy: 0.6525 - val_attr7_output_accuracy: 0.6208 - val_attr8_output_accuracy: 0.6896 - val_attr9_output_accuracy: 0.5763 - val_loss: 3.7836
# Epoch 9/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 684s 1s/step - attr10_output_accuracy: 0.3572 - attr1_output_accuracy: 0.7036 - attr2_output_accuracy: 0.6702 - attr3_output_accuracy: 0.6766 - attr4_output_accuracy: 0.6839 - attr5_output_accuracy: 0.6499 - attr6_output_accuracy: 0.6883 - attr7_output_accuracy: 0.6622 - attr8_output_accuracy: 0.7140 - attr9_output_accuracy: 0.6518 - loss: 1.0595 - val_attr10_output_accuracy: 0.2903 - val_attr1_output_accuracy: 0.6075 - val_attr2_output_accuracy: 0.5673 - val_attr3_output_accuracy: 0.6298 - val_attr4_output_accuracy: 0.6128 - val_attr5_output_accuracy: 0.6467 - val_attr6_output_accuracy: 0.6510 - val_attr7_output_accuracy: 0.6234 - val_attr8_output_accuracy: 0.6917 - val_attr9_output_accuracy: 0.5885 - val_loss: 3.9177
# Epoch 9: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Model: "efficientnetv2s_model"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 384, 384,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 384, 384,  │          0 │ input_layer[0][0] │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv (Conv2D)  │ (None, 192, 192,  │        864 │ rescaling[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_bn             │ (None, 192, 192,  │        128 │ stem_conv[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_activation     │ (None, 192, 192,  │          0 │ stem_bn[0][0]     │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_project_co… │ (None, 192, 192,  │      9,216 │ stem_activation[… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_project_bn  │ (None, 192, 192,  │        128 │ block1a_project_… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_project_ac… │ (None, 192, 192,  │          0 │ block1a_project_… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_add (Add)   │ (None, 192, 192,  │          0 │ block1a_project_… │
# │                     │ 32)               │            │ stem_activation[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_project_co… │ (None, 192, 192,  │      9,216 │ block1a_add[0][0] │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_project_bn  │ (None, 192, 192,  │        128 │ block1b_project_… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_project_ac… │ (None, 192, 192,  │          0 │ block1b_project_… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_drop        │ (None, 192, 192,  │          0 │ block1b_project_… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_add (Add)   │ (None, 192, 192,  │          0 │ block1b_drop[0][… │
# │                     │ 32)               │            │ block1a_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1c_project_co… │ (None, 192, 192,  │      9,216 │ block1b_add[0][0] │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1c_project_bn  │ (None, 192, 192,  │        128 │ block1c_project_… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1c_project_ac… │ (None, 192, 192,  │          0 │ block1c_project_… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1c_drop        │ (None, 192, 192,  │          0 │ block1c_project_… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1c_add (Add)   │ (None, 192, 192,  │          0 │ block1c_drop[0][… │
# │                     │ 32)               │            │ block1b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1d_project_co… │ (None, 192, 192,  │      9,216 │ block1c_add[0][0] │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1d_project_bn  │ (None, 192, 192,  │        128 │ block1d_project_… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1d_project_ac… │ (None, 192, 192,  │          0 │ block1d_project_… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1d_drop        │ (None, 192, 192,  │          0 │ block1d_project_… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1d_add (Add)   │ (None, 192, 192,  │          0 │ block1d_drop[0][… │
# │                     │ 32)               │            │ block1c_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_conv │ (None, 96, 96,    │     36,864 │ block1d_add[0][0] │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_bn   │ (None, 96, 96,    │        512 │ block2a_expand_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_act… │ (None, 96, 96,    │          0 │ block2a_expand_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_project_co… │ (None, 96, 96,    │      8,192 │ block2a_expand_a… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_project_bn  │ (None, 96, 96,    │        256 │ block2a_project_… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_conv │ (None, 96, 96,    │    147,456 │ block2a_project_… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_bn   │ (None, 96, 96,    │      1,024 │ block2b_expand_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_act… │ (None, 96, 96,    │          0 │ block2b_expand_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_project_co… │ (None, 96, 96,    │     16,384 │ block2b_expand_a… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_project_bn  │ (None, 96, 96,    │        256 │ block2b_project_… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_drop        │ (None, 96, 96,    │          0 │ block2b_project_… │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_add (Add)   │ (None, 96, 96,    │          0 │ block2b_drop[0][… │
# │                     │ 64)               │            │ block2a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_expand_conv │ (None, 96, 96,    │    147,456 │ block2b_add[0][0] │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_expand_bn   │ (None, 96, 96,    │      1,024 │ block2c_expand_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_expand_act… │ (None, 96, 96,    │          0 │ block2c_expand_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_project_co… │ (None, 96, 96,    │     16,384 │ block2c_expand_a… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_project_bn  │ (None, 96, 96,    │        256 │ block2c_project_… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_drop        │ (None, 96, 96,    │          0 │ block2c_project_… │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_add (Add)   │ (None, 96, 96,    │          0 │ block2c_drop[0][… │
# │                     │ 64)               │            │ block2b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_expand_conv │ (None, 96, 96,    │    147,456 │ block2c_add[0][0] │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_expand_bn   │ (None, 96, 96,    │      1,024 │ block2d_expand_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_expand_act… │ (None, 96, 96,    │          0 │ block2d_expand_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_project_co… │ (None, 96, 96,    │     16,384 │ block2d_expand_a… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_project_bn  │ (None, 96, 96,    │        256 │ block2d_project_… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_drop        │ (None, 96, 96,    │          0 │ block2d_project_… │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_add (Add)   │ (None, 96, 96,    │          0 │ block2d_drop[0][… │
# │                     │ 64)               │            │ block2c_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2e_expand_conv │ (None, 96, 96,    │    147,456 │ block2d_add[0][0] │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2e_expand_bn   │ (None, 96, 96,    │      1,024 │ block2e_expand_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2e_expand_act… │ (None, 96, 96,    │          0 │ block2e_expand_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2e_project_co… │ (None, 96, 96,    │     16,384 │ block2e_expand_a… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2e_project_bn  │ (None, 96, 96,    │        256 │ block2e_project_… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2e_drop        │ (None, 96, 96,    │          0 │ block2e_project_… │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2e_add (Add)   │ (None, 96, 96,    │          0 │ block2e_drop[0][… │
# │                     │ 64)               │            │ block2d_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2f_expand_conv │ (None, 96, 96,    │    147,456 │ block2e_add[0][0] │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2f_expand_bn   │ (None, 96, 96,    │      1,024 │ block2f_expand_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2f_expand_act… │ (None, 96, 96,    │          0 │ block2f_expand_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2f_project_co… │ (None, 96, 96,    │     16,384 │ block2f_expand_a… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2f_project_bn  │ (None, 96, 96,    │        256 │ block2f_project_… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2f_drop        │ (None, 96, 96,    │          0 │ block2f_project_… │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2f_add (Add)   │ (None, 96, 96,    │          0 │ block2f_drop[0][… │
# │                     │ 64)               │            │ block2e_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2g_expand_conv │ (None, 96, 96,    │    147,456 │ block2f_add[0][0] │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2g_expand_bn   │ (None, 96, 96,    │      1,024 │ block2g_expand_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2g_expand_act… │ (None, 96, 96,    │          0 │ block2g_expand_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2g_project_co… │ (None, 96, 96,    │     16,384 │ block2g_expand_a… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2g_project_bn  │ (None, 96, 96,    │        256 │ block2g_project_… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2g_drop        │ (None, 96, 96,    │          0 │ block2g_project_… │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2g_add (Add)   │ (None, 96, 96,    │          0 │ block2g_drop[0][… │
# │                     │ 64)               │            │ block2f_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_conv │ (None, 48, 48,    │    147,456 │ block2g_add[0][0] │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_bn   │ (None, 48, 48,    │      1,024 │ block3a_expand_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_act… │ (None, 48, 48,    │          0 │ block3a_expand_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_project_co… │ (None, 48, 48,    │     24,576 │ block3a_expand_a… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_project_bn  │ (None, 48, 48,    │        384 │ block3a_project_… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_conv │ (None, 48, 48,    │    331,776 │ block3a_project_… │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_bn   │ (None, 48, 48,    │      1,536 │ block3b_expand_c… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_act… │ (None, 48, 48,    │          0 │ block3b_expand_b… │
# │ (Activation)        │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_project_co… │ (None, 48, 48,    │     36,864 │ block3b_expand_a… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_project_bn  │ (None, 48, 48,    │        384 │ block3b_project_… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_drop        │ (None, 48, 48,    │          0 │ block3b_project_… │
# │ (Dropout)           │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_add (Add)   │ (None, 48, 48,    │          0 │ block3b_drop[0][… │
# │                     │ 96)               │            │ block3a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_expand_conv │ (None, 48, 48,    │    331,776 │ block3b_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_expand_bn   │ (None, 48, 48,    │      1,536 │ block3c_expand_c… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_expand_act… │ (None, 48, 48,    │          0 │ block3c_expand_b… │
# │ (Activation)        │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_project_co… │ (None, 48, 48,    │     36,864 │ block3c_expand_a… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_project_bn  │ (None, 48, 48,    │        384 │ block3c_project_… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_drop        │ (None, 48, 48,    │          0 │ block3c_project_… │
# │ (Dropout)           │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_add (Add)   │ (None, 48, 48,    │          0 │ block3c_drop[0][… │
# │                     │ 96)               │            │ block3b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_expand_conv │ (None, 48, 48,    │    331,776 │ block3c_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_expand_bn   │ (None, 48, 48,    │      1,536 │ block3d_expand_c… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_expand_act… │ (None, 48, 48,    │          0 │ block3d_expand_b… │
# │ (Activation)        │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_project_co… │ (None, 48, 48,    │     36,864 │ block3d_expand_a… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_project_bn  │ (None, 48, 48,    │        384 │ block3d_project_… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_drop        │ (None, 48, 48,    │          0 │ block3d_project_… │
# │ (Dropout)           │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_add (Add)   │ (None, 48, 48,    │          0 │ block3d_drop[0][… │
# │                     │ 96)               │            │ block3c_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3e_expand_conv │ (None, 48, 48,    │    331,776 │ block3d_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3e_expand_bn   │ (None, 48, 48,    │      1,536 │ block3e_expand_c… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3e_expand_act… │ (None, 48, 48,    │          0 │ block3e_expand_b… │
# │ (Activation)        │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3e_project_co… │ (None, 48, 48,    │     36,864 │ block3e_expand_a… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3e_project_bn  │ (None, 48, 48,    │        384 │ block3e_project_… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3e_drop        │ (None, 48, 48,    │          0 │ block3e_project_… │
# │ (Dropout)           │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3e_add (Add)   │ (None, 48, 48,    │          0 │ block3e_drop[0][… │
# │                     │ 96)               │            │ block3d_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3f_expand_conv │ (None, 48, 48,    │    331,776 │ block3e_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3f_expand_bn   │ (None, 48, 48,    │      1,536 │ block3f_expand_c… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3f_expand_act… │ (None, 48, 48,    │          0 │ block3f_expand_b… │
# │ (Activation)        │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3f_project_co… │ (None, 48, 48,    │     36,864 │ block3f_expand_a… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3f_project_bn  │ (None, 48, 48,    │        384 │ block3f_project_… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3f_drop        │ (None, 48, 48,    │          0 │ block3f_project_… │
# ...
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7e_se_reshape  │ (None, 1, 1,      │          0 │ block7e_se_squee… │
# │ (Reshape)           │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7e_se_reduce   │ (None, 1, 1, 160) │    614,560 │ block7e_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7e_se_expand   │ (None, 1, 1,      │    618,240 │ block7e_se_reduc… │
# │ (Conv2D)            │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7e_se_excite   │ (None, 12, 12,    │          0 │ block7e_activati… │
# │ (Multiply)          │ 3840)             │            │ block7e_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7e_project_co… │ (None, 12, 12,    │  2,457,600 │ block7e_se_excit… │
# │ (Conv2D)            │ 640)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7e_project_bn  │ (None, 12, 12,    │      2,560 │ block7e_project_… │
# │ (BatchNormalizatio… │ 640)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7e_drop        │ (None, 12, 12,    │          0 │ block7e_project_… │
# │ (Dropout)           │ 640)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7e_add (Add)   │ (None, 12, 12,    │          0 │ block7e_drop[0][… │
# │                     │ 640)              │            │ block7d_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7f_expand_conv │ (None, 12, 12,    │  2,457,600 │ block7e_add[0][0] │
# │ (Conv2D)            │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7f_expand_bn   │ (None, 12, 12,    │     15,360 │ block7f_expand_c… │
# │ (BatchNormalizatio… │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7f_expand_act… │ (None, 12, 12,    │          0 │ block7f_expand_b… │
# │ (Activation)        │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7f_dwconv2     │ (None, 12, 12,    │     34,560 │ block7f_expand_a… │
# │ (DepthwiseConv2D)   │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7f_bn          │ (None, 12, 12,    │     15,360 │ block7f_dwconv2[… │
# │ (BatchNormalizatio… │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7f_activation  │ (None, 12, 12,    │          0 │ block7f_bn[0][0]  │
# │ (Activation)        │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7f_se_squeeze  │ (None, 3840)      │          0 │ block7f_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7f_se_reshape  │ (None, 1, 1,      │          0 │ block7f_se_squee… │
# │ (Reshape)           │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7f_se_reduce   │ (None, 1, 1, 160) │    614,560 │ block7f_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7f_se_expand   │ (None, 1, 1,      │    618,240 │ block7f_se_reduc… │
# │ (Conv2D)            │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7f_se_excite   │ (None, 12, 12,    │          0 │ block7f_activati… │
# │ (Multiply)          │ 3840)             │            │ block7f_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7f_project_co… │ (None, 12, 12,    │  2,457,600 │ block7f_se_excit… │
# │ (Conv2D)            │ 640)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7f_project_bn  │ (None, 12, 12,    │      2,560 │ block7f_project_… │
# │ (BatchNormalizatio… │ 640)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7f_drop        │ (None, 12, 12,    │          0 │ block7f_project_… │
# │ (Dropout)           │ 640)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7f_add (Add)   │ (None, 12, 12,    │          0 │ block7f_drop[0][… │
# │                     │ 640)              │            │ block7e_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7g_expand_conv │ (None, 12, 12,    │  2,457,600 │ block7f_add[0][0] │
# │ (Conv2D)            │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7g_expand_bn   │ (None, 12, 12,    │     15,360 │ block7g_expand_c… │
# │ (BatchNormalizatio… │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7g_expand_act… │ (None, 12, 12,    │          0 │ block7g_expand_b… │
# │ (Activation)        │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7g_dwconv2     │ (None, 12, 12,    │     34,560 │ block7g_expand_a… │
# │ (DepthwiseConv2D)   │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7g_bn          │ (None, 12, 12,    │     15,360 │ block7g_dwconv2[… │
# │ (BatchNormalizatio… │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7g_activation  │ (None, 12, 12,    │          0 │ block7g_bn[0][0]  │
# │ (Activation)        │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7g_se_squeeze  │ (None, 3840)      │          0 │ block7g_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7g_se_reshape  │ (None, 1, 1,      │          0 │ block7g_se_squee… │
# │ (Reshape)           │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7g_se_reduce   │ (None, 1, 1, 160) │    614,560 │ block7g_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7g_se_expand   │ (None, 1, 1,      │    618,240 │ block7g_se_reduc… │
# │ (Conv2D)            │ 3840)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7g_se_excite   │ (None, 12, 12,    │          0 │ block7g_activati… │
# │ (Multiply)          │ 3840)             │            │ block7g_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7g_project_co… │ (None, 12, 12,    │  2,457,600 │ block7g_se_excit… │
# │ (Conv2D)            │ 640)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7g_project_bn  │ (None, 12, 12,    │      2,560 │ block7g_project_… │
# │ (BatchNormalizatio… │ 640)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7g_drop        │ (None, 12, 12,    │          0 │ block7g_project_… │
# │ (Dropout)           │ 640)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7g_add (Add)   │ (None, 12, 12,    │          0 │ block7g_drop[0][… │
# │                     │ 640)              │            │ block7f_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_conv (Conv2D)   │ (None, 12, 12,    │    819,200 │ block7g_add[0][0] │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_bn              │ (None, 12, 12,    │      5,120 │ top_conv[0][0]    │
# │ (BatchNormalizatio… │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_activation      │ (None, 12, 12,    │          0 │ top_bn[0][0]      │
# │ (Activation)        │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ top_activation[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ top_activation[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ top_activation[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ top_activation[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ top_activation[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ top_activation[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ top_activation[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ top_activation[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ top_activation[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ top_activation[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 1280)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 1280)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 1280)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 1280)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 1280)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 1280)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 1280)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 1280)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 1280)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 1280)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attr1_output        │ (None, 13)        │     16,653 │ dropout[0][0]     │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attr2_output        │ (None, 5)         │      6,405 │ dropout_1[0][0]   │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attr3_output        │ (None, 3)         │      3,843 │ dropout_2[0][0]   │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attr4_output        │ (None, 8)         │     10,248 │ dropout_3[0][0]   │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attr5_output        │ (None, 3)         │      3,843 │ dropout_4[0][0]   │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attr6_output        │ (None, 4)         │      5,124 │ dropout_5[0][0]   │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attr7_output        │ (None, 7)         │      8,967 │ dropout_6[0][0]   │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attr8_output        │ (None, 5)         │      6,405 │ dropout_7[0][0]   │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attr9_output        │ (None, 5)         │      6,405 │ dropout_8[0][0]   │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attr10_output       │ (None, 7)         │      8,967 │ dropout_9[0][0]   │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 352,445,978 (1.31 GB)
#  Trainable params: 117,311,132 (447.51 MB)
#  Non-trainable params: 512,576 (1.96 MB)
#  Optimizer params: 234,622,270 (895.01 MB)
